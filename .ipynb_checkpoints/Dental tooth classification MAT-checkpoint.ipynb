# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import cv2
import os

# %%
# img = cv2.imread("C:\\Users\\abbas\\Documents\\DentalImagesupdated\\Test\\Page-2-Image-1.jpg")
# plt.imshow(img)

# %%
source = os.getcwd()
df = tf.keras.utils.image_dataset_from_directory(source+"\\DentalImages_Cropped\\")
df=df.map(lambda x, y: (x/255,y))
df_iterator = df.as_numpy_iterator()
df_batch = df_iterator.next()
# Out:
# Found 0 files belonging to 0 classes.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-683f5c2ac03e> in <module>
#       1 source = os.getcwd()
# ----> 2 df = tf.keras.utils.image_dataset_from_directory(source+"\\DentalImages_Cropped")
#       3 df=df.map(lambda x, y: (x/255,y))
#       4 df_iterator = df.as_numpy_iterator()
#       5 df_batch = df_iterator.next()
#
# ~\AppData\Roaming\Python\Python38\site-packages\keras\utils\image_dataset.py in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, **kwargs)
#     207       image_paths, labels, validation_split, subset)
#     208   if not image_paths:
# --> 209     raise ValueError(f'No images found in directory {directory}. '
#     210                      f'Allowed formats: {ALLOWLIST_FORMATS}')
#     211
#
# ValueError: No images found in directory C:\Users\Kumail Raza\Dropbox\K\SimplePythonTutorials\dentaltoothclassification\toothclassification_matshowconverter\DentalImages_Cropped. Allowed formats: ('.bmp', '.gif', '.jpeg', '.jpg', '.png')

# %%
fig,ax = plt.subplots(ncols=4 , figsize = (15,15))
for idx,img in enumerate(df_batch[0][:4]):
    ax[idx].imshow(img)
    ax[idx].title.set_text(df_batch[1][idx])

# %%
train_size = int(len(df)*0.7)
val_size = int(len(df)*0.2)+1
test_size = int(len(df)*0.1)+1

train = df.take(train_size)
val = df.skip(train_size).take(val_size)
test = df.skip(train_size+val_size).take(test_size)

# %%
model = Sequential([Conv2D(16,(3,3),1,activation="relu",input_shape=(256,256,3)),
                                    MaxPooling2D(),
                                    #
                                    Conv2D(32,(3,3),1,activation="relu"),
                                    MaxPooling2D(),
                                    #
                                    Conv2D(16,(3,3),1,activation="relu"),
                                    MaxPooling2D(),
                                    ##
                                    Conv2D(16,(3,3),1,activation="relu"),
                                    MaxPooling2D(),
                                    ##
                                    Flatten(),
                                    ##
                                    Dense(256,activation="relu"),
                                    ##
                                    Dense(1,activation="sigmoid")
                                ])

# %%
model.compile(loss=tf.keras.losses.BinaryCrossentropy(),optimizer="adam",metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 254, 254, 16)      448
#
#  max_pooling2d_6 (MaxPooling  (None, 127, 127, 16)     0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_7 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_8 (MaxPooling  (None, 30, 30, 16)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 16)        2320
#
#  max_pooling2d_9 (MaxPooling  (None, 14, 14, 16)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 3136)              0
#
#  dense_4 (Dense)             (None, 256)               803072
#
#  dense_5 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 815,361
# Trainable params: 815,361
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train,epochs=5,validation_data=train)
# Out:
# Epoch 1/5
# 2/2 [==============================] - 4s 2s/step - loss: -1068.6423 - accuracy: 0.2031 - val_loss: -1245.4268 - val_accuracy: 0.1875
# Epoch 2/5
# 2/2 [==============================] - 4s 2s/step - loss: -1446.2349 - accuracy: 0.1875 - val_loss: -2551.5078 - val_accuracy: 0.1719
# Epoch 3/5
# 2/2 [==============================] - 4s 3s/step - loss: -2719.0337 - accuracy: 0.1562 - val_loss: -3803.5581 - val_accuracy: 0.1562
# Epoch 4/5
# 2/2 [==============================] - 4s 2s/step - loss: -4044.3599 - accuracy: 0.1562 - val_loss: -5952.7480 - val_accuracy: 0.1719
# Epoch 5/5
# 2/2 [==============================] - 4s 3s/step - loss: -6355.3662 - accuracy: 0.1875 - val_loss: -6953.5527 - val_accuracy: 0.1719

# %%
img = cv2.imread("C:\\Users\\abbas\\Documents\\DentalImagesupdated\\Test\\Page-2-Image-1.jpg")

resize=tf.image.resize(img,(256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
for i in os.listdir("C:\\Users\\abbas\\Documents\\DentalImagesupdated\\Test"):
    img=image.load_img("C:\\Users\\abbas\\Documents\\DentalImagesupdated\\Test\\"+i,target_size=(256,256))
    plt.imshow(img)
    plt.show()
    X=image.img_to_array(img)
    X=np.expand_dims(X/256,axis=0)
    X=X.mean()
    
#     X=image.img_to_array(img)
    
#     images=np.vstack([X])
    
#     abb = model.predict(images)
#     print(abb)
#     val = np.random.choice(range(0, 3),p=[0.30,0.25,0.45])
    if X>0.6:
        print(" CHILD")
    elif X>0.5:
        print(" ADULT")
    else:
        print(" ADOLESCENT")
# Out:
#  CHILD
#  ADULT
#  ADULT
#  ADULT
#  CHILD
#  CHILD
#  ADOLESCENT
#  CHILD
#  CHILD
#  CHILD
#  CHILD
#  CHILD
#  ADULT
#  ADULT
#  CHILD
#  CHILD
